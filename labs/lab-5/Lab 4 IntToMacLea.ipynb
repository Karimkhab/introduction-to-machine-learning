# %% [markdown]
# # Lab-4:
# In this lab, we will examine some classifiers, and the regularization concept in the classification problem.
# Also, we will see
#
# ### Objectives:
# 1. Lasso and Ridge
# 2. Naïve Bayes
# 3. KNN
# 4. Cross Validation
#
# ---
# ## Lasso and Ridge
# Both models are the regularized forms of the linear regression.
# Lass with L1 regularization and Ridge with L2 regularization.
# Both act as a constraint region for the coefficients/weight, where they must reside in.
#
# ### Issues:
# 1. When to use Lasso?
#
# 2. When to use Ridge?
#
# 3. Since it is hard to decide the parameters influence, How we can decide which regularization? and decide the value of lambda?

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading Boston dataset
# Housing-Prices Values in Suburbs of Boston.

# %%
import pandas as pd
import numpy as np
# This dataset is biased, but we will use it for educational purposes
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
X = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=1/8, random_state=123)

# %% [markdown]
# ## Fitting both Lasso and Ridge
#
# ### Task 1:
#
# Fit two models: Lasso and Ridge - with the default alpha-.
# Then print their coefficients and notice the difference.

# %%
from sklearn.linear_model import Lasso, Ridge

# write code here
lasso = Lasso().fit(x_train, y_train)
ridge = Ridge().fit(x_train, y_train)

print("Lasso Coefficient:", *lasso.coef_, sep='\n\t')
print("Ridge Coefficient:", *ridge.coef_, sep='\n\t')
print('Sum of lasso abs values:', np.sum(np.abs(lasso.coef_)))
print('Sum of ridge abs values:', np.sum(np.abs(ridge.coef_)))
# Out:
# Lasso Coefficient:
# 	-0.06296576330463606
# 	0.035095663971902495
# 	0.0
# 	0.0
# 	-0.0
# 	2.269791338462823
# 	0.0006779558466117092
# 	-0.645065772635446
# 	0.19354572704933154
# 	-0.013508702669918594
# 	-0.645345872646641
# 	0.004490421848032127
# 	-0.6731506757847044
# Ridge Coefficient:
# 	-0.11105798056135216
# 	0.036585280482907045
# 	0.046921285415925086
# 	0.6038241348013773
# 	-6.974605652267571
# 	5.11864285160246
# 	-0.026987022704629462
# 	-1.228242795071093
# 	0.24913980673173003
# 	-0.013989976538036502
# 	-0.8478133115629455
# 	0.006954220877156476
# 	-0.46881648708544393
# Sum of lasso abs values: 4.543637894220048
# Sum of ridge abs values: 15.733580805702628

# %% [markdown]
# ### Task 2:
# Let's try different values for alpha for Lasso and Ridge regressors then
# plot the validation loss.

# %%
import matplotlib.pylab as plt
from sklearn.metrics import mean_squared_error
# %matplotlib inline

lasso_alphas = [0.3, 0.5, 1, 1.1, 1.2, 1.3, 1.5, 2, 2.2, 2.5]
ridge_alphas = [50, 200, 300, 350, 400, 500, 600, 700, 1000, 1200]
lasso_losses = []
ridge_losses = []
for i in range(len(lasso_alphas)):
    # Create a Lasso regressor with the alpha value.
    # Fit it to the training set, then get the prediction of the validation set (x_val).
    # calculate the mean squared error loss, then append it to the losses array
    lasso = Lasso(alpha=lasso_alphas[i]).fit(x_train, y_train)

    y_pred = lasso.predict(x_val)
    mse = mean_squared_error(y_pred, y_val)
    lasso_losses.append(mse)

    ridge = Ridge(alpha=lasso_alphas[i]).fit(x_train, y_train)

    y_pred = ridge.predict(x_val)
    mse = mean_squared_error(y_pred, y_val)
    ridge_losses.append(mse)

plt.suptitle('The effect of changing alpha on MSE for lasso and ridge')



# plt.figure(figsize=(10, 8))
fig, (ax1, ax2) = plt.subplots(1,2, sharey=True)
fig.suptitle('Aligning x-axis using sharex')

ax1.plot(lasso_alphas, lasso_losses, label='lasso')
ax1.legend()
ax1.set(xlabel='alpha', ylabel='MSE')

ax2.plot(ridge_alphas, ridge_losses, label='ridge')
ax2.legend()
ax2.set(xlabel='alpha', ylabel='MSE')

plt.show()

lasso_best_alpha = lasso_alphas[np.argmin(lasso_losses)]
ridge_best_alpha = ridge_alphas[np.argmin(ridge_losses)]
print("Best value of alpha for lasso:", lasso_best_alpha)
print("Best value of alpha for ridge:", ridge_best_alpha)
# Out:
# Best value of alpha for lasso: 1.3
# Best value of alpha for ridge: 50

# %% [markdown]
# Measuring the loss on the test set with Lasso and ridge regressors with the
# best alpha.

# %%
lasso = Lasso(lasso_best_alpha)
lasso.fit(x_train, y_train)
y_pred = lasso.predict(x_test)
print("Lasso MSE on test set:", mean_squared_error(y_test, y_pred))

ridge = Ridge(ridge_best_alpha)
ridge.fit(x_train, y_train)
y_pred = ridge.predict(x_test)
print("Ridge MSE on test set:", mean_squared_error(y_test, y_pred))
# Out:
# Lasso MSE on test set: 31.95376288082982
# Ridge MSE on test set: 30.16332632070601

# %%
# feature_names =

lasso_alphas = [1, 1.1, 1.2, 1.3, 1.5, 2, 2.2, 2.5, 3, 5]
ridge_alphas = [100, 200, 300, 350, 400, 500, 600, 700, 1000, 1200, 2000, 3000]
lasso_coefs_ = np.zeros((len(lasso_alphas), len(X[0])))
ridge_coefs_ = np.zeros((len(ridge_alphas), len(X[0])))
for i in range(len(lasso_alphas)):
    lasso = Lasso(alpha=lasso_alphas[i])
    lasso.fit(x_train, y_train)
    lasso_coefs_[i] = lasso.coef_

for i in range(len(ridge_alphas)):
    ridge = Ridge(alpha=ridge_alphas[i])
    ridge.fit(x_train, y_train)
    ridge_coefs_[i] = ridge.coef_

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
fig.suptitle('The effect of changing alpha on the coefficients of lasso and ridge')

for idx in range(len(X[0])):
    ax1.plot(lasso_alphas, lasso_coefs_[:, idx], label=f'feature {idx}')
ax1.legend()
ax1.set(xlabel='alpha', ylabel='coefs')

for idx in range(len(X[0])):
    ax2.plot(ridge_alphas, ridge_coefs_[:, idx], label=f'feature {idx}')
ax2.legend()
ax2.set(xlabel='alpha', ylabel='coefs')

plt.show()

# %% [markdown]
# ## Loading the iris dataset
# Dataset of 3 types/classes of flowers with 4 features. Suitable for classification!

# %%
from sklearn.datasets import load_digits, load_iris

X, y = load_digits(return_X_y=True)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# We will show why we didn't split a validation set.

# %% [markdown]
# ## Naïve Bayes
# We will use the Gaussian Naïve Bayes, that deals -as a assumption- with the continous features as gaussian variables to compute their probability.
#
# $$P(x_i|y) = \frac{1}{\sqrt{2\pi\sigma_y^2}}exp(-\frac{(x_i - \mu_y)^2}{2\sigma_y^2})$$
#
# While $\mu_y$ and $\sigma_y^2$ are the mean and the variance of the feature $i$ for class $y$.
#
# Note: The different naive Bayes classifiers differ mainly by the assumptions they make regarding the distribution of $P(x_i|y)$.
#
# ___
# What are the pros and cons of Naive bayes classifier?
# ___

# %% [markdown]
# Let's train a naive-bayes model and check the test accuracy.

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gauss_nb = GaussianNB()
gauss_nb.fit(x_train, y_train)
y_pred = gauss_nb.predict(x_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8666666666666667

# %% [markdown]
# ## K nearest neighbour classifier
# 1. What are the pros and cons of KNN?

# %% [markdown]
# ___
# Let's do the same with KNN classifier.
#
#
# Rescale the features first.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9722222222222222

# %% [markdown]
# Let's tune the hyperparameter $n\_neighbors$ in the KNN classifier object using the cross-validation.
#
# ___
# ## Cross Validation
# Cross validation comes as an alternative for the validation set splitting.
#
# Note: that's why we didn't make a validation set.

# %%
from sklearn.model_selection import cross_val_score
import matplotlib.pylab as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
# %matplotlib inline

Ks = list(range(1, 20))
cv_scores = []
for K in Ks:
    knn = KNeighborsClassifier(n_neighbors=K)
    scores = cross_val_score(knn, x_train, y_train,
                             cv=7, scoring='accuracy')
    avg_score = np.mean(scores)
    cv_scores.append(avg_score)

plt.title('The effect of changing K on accuracy')
plt.plot(Ks, cv_scores)
plt.xlabel('K')
plt.xticks(Ks)
plt.ylabel('CV Average accuracy')
plt.show()
print('Best K:', Ks[np.argmax(cv_scores)])
# Out:
# Best K: 5

# %% [markdown]
# In KNN classifier, there are several hyperparamters to tune, tuning them one
# by one is exhaustive approach. Let's try a better approach called GridSearchCV.
#
# ### GridSearchCV
# In GridSearch Cross-validation, you give different values for each hyperparamter and it will try all combinations for you.
# At the end, it will return the best combination of hyperparamters that got the best cross-validation score.
#
# ### Task 3:
# Use gridsearch to tune 3 hyperparameters:
#
# 1. $n\_neighbors$: [1, 2, . . ., 10]
# 2. $weights$: ['uniform', 'distance']
# 3. $metric$: ['euclidean', 'manhattan', 'chebyshev', 'cosine']
#
# Check this [link](https://scikit-learn.org/stable/modules/grid_search.html)
# for help.
#
# Then measure the accuracy on the test set.

# %%
from sklearn.model_selection import GridSearchCV

# Modify the next lines to run GridSearchCV with cv=7
param_grid = {'n_neighbors':list(range(1, 11)),
              'weights':['uniform', 'distance'],
              'metric':['euclidean', 'manhattan', 'chebyshev', 'cosine']
              }

# create a GridSearch cross validation with cv=7,
# and accuracy as scoring, and specify param_grid


grid_search_clf = GridSearchCV(
    estimator=KNeighborsClassifier(), 
    param_grid = param_grid, 
    cv = 7
).fit(x_train, y_train)
# then train on the train dataset


means = grid_search_clf.cv_results_['mean_test_score']
stds = grid_search_clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid_search_clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
        % (mean, std * 2, params))
print()
print("Best parameters set found on development set:")
print()
print(grid_search_clf.best_params_)

y_pred = grid_search_clf.predict(x_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.971 (+/-0.022) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.971 (+/-0.022) for {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# 0.969 (+/-0.010) for {'metric': 'euclidean', 'n_neighbors': 2, 'weights': 'uniform'}
# 0.971 (+/-0.022) for {'metric': 'euclidean', 'n_neighbors': 2, 'weights': 'distance'}
# 0.976 (+/-0.015) for {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.976 (+/-0.017) for {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# 0.978 (+/-0.016) for {'metric': 'euclidean', 'n_neighbors': 4, 'weights': 'uniform'}
# 0.979 (+/-0.016) for {'metric': 'euclidean', 'n_neighbors': 4, 'weights': 'distance'}
# 0.978 (+/-0.015) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.980 (+/-0.014) for {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# 0.974 (+/-0.019) for {'metric': 'euclidean', 'n_neighbors': 6, 'weights': 'uniform'}
# 0.977 (+/-0.013) for {'metric': 'euclidean', 'n_neighbors': 6, 'weights': 'distance'}
# 0.975 (+/-0.016) for {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.977 (+/-0.013) for {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}
# 0.971 (+/-0.019) for {'metric': 'euclidean', 'n_neighbors': 8, 'weights': 'uniform'}
# 0.975 (+/-0.013) for {'metric': 'euclidean', 'n_neighbors': 8, 'weights': 'distance'}
# 0.970 (+/-0.017) for {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.973 (+/-0.019) for {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# 0.969 (+/-0.021) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# 0.973 (+/-0.019) for {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# 0.979 (+/-0.015) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.979 (+/-0.015) for {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# 0.970 (+/-0.024) for {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'uniform'}
# 0.979 (+/-0.015) for {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'distance'}
# 0.978 (+/-0.014) for {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.979 (+/-0.013) for {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# 0.976 (+/-0.019) for {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'uniform'}
# 0.982 (+/-0.012) for {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# 0.976 (+/-0.020) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.981 (+/-0.019) for {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# 0.976 (+/-0.019) for {'metric': 'manhattan', 'n_neighbors': 6, 'weights': 'uniform'}
# 0.980 (+/-0.019) for {'metric': 'manhattan', 'n_neighbors': 6, 'weights': 'distance'}
# 0.976 (+/-0.021) for {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.979 (+/-0.023) for {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# 0.972 (+/-0.012) for {'metric': 'manhattan', 'n_neighbors': 8, 'weights': 'uniform'}
# 0.979 (+/-0.020) for {'metric': 'manhattan', 'n_neighbors': 8, 'weights': 'distance'}
# 0.971 (+/-0.014) for {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.977 (+/-0.021) for {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# 0.969 (+/-0.018) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# 0.977 (+/-0.019) for {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# 0.935 (+/-0.010) for {'metric': 'chebyshev', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.935 (+/-0.010) for {'metric': 'chebyshev', 'n_neighbors': 1, 'weights': 'distance'}
# 0.930 (+/-0.015) for {'metric': 'chebyshev', 'n_neighbors': 2, 'weights': 'uniform'}
# 0.934 (+/-0.013) for {'metric': 'chebyshev', 'n_neighbors': 2, 'weights': 'distance'}
# 0.938 (+/-0.026) for {'metric': 'chebyshev', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.942 (+/-0.025) for {'metric': 'chebyshev', 'n_neighbors': 3, 'weights': 'distance'}
# 0.931 (+/-0.014) for {'metric': 'chebyshev', 'n_neighbors': 4, 'weights': 'uniform'}
# 0.941 (+/-0.024) for {'metric': 'chebyshev', 'n_neighbors': 4, 'weights': 'distance'}
# 0.931 (+/-0.014) for {'metric': 'chebyshev', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.938 (+/-0.016) for {'metric': 'chebyshev', 'n_neighbors': 5, 'weights': 'distance'}
# 0.922 (+/-0.030) for {'metric': 'chebyshev', 'n_neighbors': 6, 'weights': 'uniform'}
# 0.940 (+/-0.018) for {'metric': 'chebyshev', 'n_neighbors': 6, 'weights': 'distance'}
# 0.923 (+/-0.022) for {'metric': 'chebyshev', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.933 (+/-0.020) for {'metric': 'chebyshev', 'n_neighbors': 7, 'weights': 'distance'}
# 0.917 (+/-0.027) for {'metric': 'chebyshev', 'n_neighbors': 8, 'weights': 'uniform'}
# 0.933 (+/-0.020) for {'metric': 'chebyshev', 'n_neighbors': 8, 'weights': 'distance'}
# 0.917 (+/-0.027) for {'metric': 'chebyshev', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.928 (+/-0.024) for {'metric': 'chebyshev', 'n_neighbors': 9, 'weights': 'distance'}
# 0.914 (+/-0.019) for {'metric': 'chebyshev', 'n_neighbors': 10, 'weights': 'uniform'}
# 0.923 (+/-0.030) for {'metric': 'chebyshev', 'n_neighbors': 10, 'weights': 'distance'}
# 0.971 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 1, 'weights': 'uniform'}
# 0.971 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 1, 'weights': 'distance'}
# 0.961 (+/-0.022) for {'metric': 'cosine', 'n_neighbors': 2, 'weights': 'uniform'}
# 0.971 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 2, 'weights': 'distance'}
# 0.972 (+/-0.019) for {'metric': 'cosine', 'n_neighbors': 3, 'weights': 'uniform'}
# 0.975 (+/-0.022) for {'metric': 'cosine', 'n_neighbors': 3, 'weights': 'distance'}
# 0.967 (+/-0.014) for {'metric': 'cosine', 'n_neighbors': 4, 'weights': 'uniform'}
# 0.974 (+/-0.016) for {'metric': 'cosine', 'n_neighbors': 4, 'weights': 'distance'}
# 0.967 (+/-0.020) for {'metric': 'cosine', 'n_neighbors': 5, 'weights': 'uniform'}
# 0.971 (+/-0.020) for {'metric': 'cosine', 'n_neighbors': 5, 'weights': 'distance'}
# 0.961 (+/-0.029) for {'metric': 'cosine', 'n_neighbors': 6, 'weights': 'uniform'}
# 0.968 (+/-0.021) for {'metric': 'cosine', 'n_neighbors': 6, 'weights': 'distance'}
# 0.961 (+/-0.022) for {'metric': 'cosine', 'n_neighbors': 7, 'weights': 'uniform'}
# 0.965 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 7, 'weights': 'distance'}
# 0.961 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 8, 'weights': 'uniform'}
# 0.968 (+/-0.024) for {'metric': 'cosine', 'n_neighbors': 8, 'weights': 'distance'}
# 0.960 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 9, 'weights': 'uniform'}
# 0.965 (+/-0.024) for {'metric': 'cosine', 'n_neighbors': 9, 'weights': 'distance'}
# 0.955 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 10, 'weights': 'uniform'}
# 0.963 (+/-0.023) for {'metric': 'cosine', 'n_neighbors': 10, 'weights': 'distance'}
#
# Best parameters set found on development set:
#
# {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# 0.9722222222222222

# %% [markdown]
# ---
# When the hyper-parameter(s) range is big, grid-search becomes exponentially inefficient.
# What other approaches can we use to solve this problem?

# %% [markdown]
# ## Further reading
#
# [L1 vs L2](https://www.analyticssteps.com/blogs/l2-and-l1-regularization-machine-learning),
# What if we used something other than the norm? like $\Sigma \ln(w_j^2)$
#
# [Elastic net](https://scikit-learn.org/stable/modules/linear_model.html#elastic-net)
#
# [Huber regularization](http://www.stephanmandt.com/papers/ECML_2016.pdf),
# what if we switch the condition?
#
# [Pruned Cross Validation](https://piotrekga.github.io/Pruned-Cross-Validation/)
