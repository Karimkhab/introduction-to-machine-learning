# %%
import pandas as pd
import json

# %%
train_data = []
with open('/Users/karimkhabib/Documents/Innopolis/Second course (B25 - B26)/introduction-to-machine-learning/yandex/hw-03/ml_trainings.alien_translation/train', 'r', encoding='utf-8') as f:
    for line in f:
        train_data.append(json.loads(line))

val_data = []
with open('/Users/karimkhabib/Documents/Innopolis/Second course (B25 - B26)/introduction-to-machine-learning/yandex/hw-03/ml_trainings.alien_translation/val', 'r', encoding='utf-8') as f:
    for line in f:
        val_data.append(json.loads(line))

print(train_data[0], val_data[0])
# Out:
# {'dst': '- Intriguing.', 'src': '◄▴◓◠▨ ◨▽◠▦◈◬◓▪▼◬▵'} {'dst': 'The hosts regrouped, and Bouchard evened the score again, scoring a goal with a 27-37 man advantage.', 'src': "◘◚ ◞◠▷◫◀◗ ▫◠▨◬◎ ▨◪▦◈◫▦◫ ▫◧▻▱◠◈▪ ◚◪ ◝◂▾▼▷◠◓◈'◬▦ 27:37'◈▴▨◗ ◕◂▱◭ ◀◗◓ ▨▴▢ ◈◠▷◠ ◞▨◂◓◨ ▴◒◗▫▱◪◈◗▵"}
