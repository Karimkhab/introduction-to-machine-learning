# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
# /var/folders/ft/pkyxbgxd5qqcsz8hx6b9xk480000gn/T/ipykernel_27489/274144450.py:1: DtypeWarning: Columns (11,28,46,51,57,59,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('train.csv')
#    snapshot_dt  agreement   customer  target a76154d74182dbdbe69cc30b71b94709  \
# 0   1551398400  206429777   99860345       0                              inf
# 1   1548979200  356198936  143066693       0                      2,857142857
# 2   1548979200  181800968   97211246       0                               -1
# 3   1538352000  126060285   26277371       0                              NaN
# 4   1541030400  226351733  122502600       0                               -1
#
#   713bc35ae4a64ec4790712ab3ff2e7b0 142642bce57cac3a54f26d9c4a4ea164  \
# 0                      1,377262826                                0
# 1                      0,718872084                      26,66666667
# ...

# %%
df.shape
# Out:
# (90329, 66)

# %%
df.isna().sum()
# Out:
# snapshot_dt                             0
# agreement                               0
# customer                                0
# target                                  0
# a76154d74182dbdbe69cc30b71b94709    26750
#                                     ...
# 8ce7e1924c8891f9ca267c926a71d4ad    26750
# 7e9b2e50b011024e81f5c646fb436e28      174
# bb496ecdfaf5fc8772d00ae34048ec29    76409
# 5a105e8b9d40e1329780d62ea2265d8a        0
# ad0234829205b9033196ba818f7a872b        0
# Length: 66, dtype: int64

# %%
int_col = ['snapshot_dt','agreement','customer','target']
df[int_col].head()
# Out:
#    snapshot_dt  agreement   customer  target
# 0   1551398400  206429777   99860345       0
# 1   1548979200  356198936  143066693       0
# 2   1548979200  181800968   97211246       0
# 3   1538352000  126060285   26277371       0
# 4   1541030400  226351733  122502600       0

# %%
df.describe()
# Out:
#         snapshot_dt     agreement      customer        target  \
# count  9.032900e+04  9.032900e+04  9.032900e+04  90329.000000
# mean   1.535878e+09  2.324536e+08  9.889035e+07      0.020005
# std    9.897276e+06  1.043508e+08  6.048675e+07      0.140017
# min    1.519862e+09  2.972487e+07  2.075046e+07      0.000000
# 25%    1.527811e+09  1.543988e+08  4.511717e+07      0.000000
# 50%    1.535760e+09  2.315195e+08  8.741529e+07      0.000000
# 75%    1.543622e+09  3.382529e+08  1.349377e+08      0.000000
# max    1.551398e+09  3.980932e+08  2.908694e+08      1.000000
#
#        47b359b06b472245ebf392f89c1984d9  d1e92bd0813153b4426efe76c284962a  \
# count                      13920.000000                      13920.000000
# mean                           0.118391                          0.000144
# std                            0.428768                          0.011986
# min                            0.000000                          0.000000
# ...

# %%
df.dtypes
# Out:
# snapshot_dt                           int64
# agreement                             int64
# customer                              int64
# target                                int64
# a76154d74182dbdbe69cc30b71b94709     object
#                                      ...
# 8ce7e1924c8891f9ca267c926a71d4ad    float64
# 7e9b2e50b011024e81f5c646fb436e28     object
# bb496ecdfaf5fc8772d00ae34048ec29    float64
# 5a105e8b9d40e1329780d62ea2265d8a      int64
# ad0234829205b9033196ba818f7a872b      int64
# Length: 66, dtype: object

# %%
df['target'].hist(bins=30, figsize=(8, 4)) # bins - количество интервалов
plt.title('Гистограмма распределения')
plt.xlabel('Значения')
plt.ylabel('Частота')
plt.show()

# %%
else_col = [col for col in df.columns.tolist() if col not in int_col]
df[else_col].nunique()
# Out:
# a76154d74182dbdbe69cc30b71b94709      726
# 713bc35ae4a64ec4790712ab3ff2e7b0    19517
# 142642bce57cac3a54f26d9c4a4ea164    14139
# 64879933ebbcd196512dd71dede1b7fc        5
# 41b8f61fa021d3421510284f8e8ed8e6    13306
#                                     ...
# 8ce7e1924c8891f9ca267c926a71d4ad       29
# 7e9b2e50b011024e81f5c646fb436e28     7619
# bb496ecdfaf5fc8772d00ae34048ec29        2
# 5a105e8b9d40e1329780d62ea2265d8a        4
# ad0234829205b9033196ba818f7a872b        3
# Length: 62, dtype: int64

# %%
df[else_col].isna().sum()
# Out:
# a76154d74182dbdbe69cc30b71b94709    26750
# 713bc35ae4a64ec4790712ab3ff2e7b0      174
# 142642bce57cac3a54f26d9c4a4ea164    26750
# 64879933ebbcd196512dd71dede1b7fc      144
# 41b8f61fa021d3421510284f8e8ed8e6    26750
#                                     ...
# 8ce7e1924c8891f9ca267c926a71d4ad    26750
# 7e9b2e50b011024e81f5c646fb436e28      174
# bb496ecdfaf5fc8772d00ae34048ec29    76409
# 5a105e8b9d40e1329780d62ea2265d8a        0
# ad0234829205b9033196ba818f7a872b        0
# Length: 62, dtype: int64

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier()
target = ['target']
non_target = [col for col in df.columns.tolist() if col not in target]
df[non_target]
# Out:
#        snapshot_dt  agreement   customer a76154d74182dbdbe69cc30b71b94709  \
# 0       1551398400  206429777   99860345                              inf
# 1       1548979200  356198936  143066693                      2,857142857
# 2       1548979200  181800968   97211246                               -1
# 3       1538352000  126060285   26277371                              NaN
# 4       1541030400  226351733  122502600                               -1
# ...            ...        ...        ...                              ...
# 90324   1551398400  110273415   28423322                               -1
# 90325   1527811200  112664931   77404434                              NaN
# 90326   1535760000   76980636   47200630                              1,5
# 90327   1546300800   73816241   43131184                              NaN
# 90328   1530403200  123926193   80418297                              NaN
#
#       713bc35ae4a64ec4790712ab3ff2e7b0 142642bce57cac3a54f26d9c4a4ea164  \
# ...

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
# /var/folders/ft/pkyxbgxd5qqcsz8hx6b9xk480000gn/T/ipykernel_27489/643440041.py:1: DtypeWarning: Columns (45,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_df = pd.read_csv('test.csv')
#    snapshot_dt  agreement   customer a76154d74182dbdbe69cc30b71b94709  \
# 0   1538352000  365439355  119156836                                0
# 1   1530403200   77477821   46948414                              NaN
# 2   1530403200  190714764   85702891                              NaN
# 3   1546300800  233318015   84487348                              NaN
# 4   1548979200  318924895  122306861                              1,5
#
#   713bc35ae4a64ec4790712ab3ff2e7b0 142642bce57cac3a54f26d9c4a4ea164  \
# 0                               -1                                0
# 1                               -1                              NaN
# 2                               -1                              NaN
# ...

# %%
model.fit(df[non_target], df[target])
test_df['target'] = model.predict(test_df[non_target])
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File _catboost.pyx:2534, in _catboost.get_float_feature()
#
# File _catboost.pyx:1228, in _catboost._FloatOrNan()
#
# File _catboost.pyx:1023, in _catboost._FloatOrNanFromString()
#
# TypeError: Cannot convert 'inf' to float
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 model.fit(df[non_target], df[target])
#       2 test_df['target'] = model.predict(test_df[non_target])
#       3 test_df.head()
#
# ...

# %%
df_answer = pd.read_csv('answer.csv')
df_answer.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_answer = pd.read_csv('answer.csv')
#       2 df_answer.head()
#
# NameError: name 'pd' is not defined
