# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n1 = 2
dots1 = [[1.0, -1.0],[-1.0, 1.0]]
n2 = 2
dots2 = [[1.0, 1.0], [-1.0, -1.0]]
p0, p1 = 0.0, 0.0
dots1
# Out:
# [[1.0, -1.0], [-1.0, 1.0]]

# %%
dots1 = np.matrix(dots1)
dots2 = np.matrix(dots2)
dots2
# Out:
# matrix([[ 1.,  1.],
#         [-1., -1.],
#         [ 0.,  0.]])

# %%
plt.plot(p0, p1)
